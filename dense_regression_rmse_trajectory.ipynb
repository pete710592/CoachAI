# %% [markdown]
# ## Import requirements & Parameters setting

# %%
import os
import cv2
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import math
import glob
from tensorflow import keras
from keras import backend as K
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization, Input, ReLU
from sklearn.metrics import mean_absolute_error, mean_squared_error
from utils.functions import checkDirExist, deleteDir

batch_size = 32
epochs = 300

# set model name & model directory
model_name = '20201210_dense-rmse-position5-trajectory-100-32-64-32-16-flatten-16-3'
model_dir = os.path.join(os.getcwd(), 'models/'+model_name)
log_dir = os.path.join(os.getcwd(), 'logs/'+model_name)
checkDirExist(model_dir)

# get train data (csv)
train_dir = os.path.join(os.getcwd(), 'dataset/position_5/trajectory-100-padding/dataset-2/train/')
train_list = glob.glob(train_dir + "*.csv")

# split validation
random.Random(4).shuffle(train_list)
vaild_num = int(len(train_list)*0.1)
valid_list = train_list[:vaild_num]
train_list = train_list[vaild_num:]

# get test data (csv)
test_dir = os.path.join(os.getcwd(), 'dataset/position_5/trajectory-100-padding/dataset-2/test/')
test_list = glob.glob(test_dir + "*.csv")

print('train: ', len(train_list))
print('valid: ', len(valid_list))
print('test: ', len(test_list))
# Out:
# train:  755
# valid:  83
# test:  386

# %% [markdown]
# ## Dynamic allocation for GPU (optional)

# %%
import keras.backend.tensorflow_backend as KTF

# os.environ["CUDA_VISIBLE_DEVICES"] = "0"
config = tf.ConfigProto()
config.gpu_options.allow_growth=True   # Dynamic allocation
sess = tf.Session(config=config)
KTF.set_session(sess)

# %% [markdown]
# ## Train / Validation / Test generator definition

# %%
def train_generator():
    while(True):
        random.Random(4).shuffle(train_list)
        for i, csv in enumerate(train_list):
            df = pd.read_csv(csv)
            data = []
            diff = []
            for idx in df.index:
                diff.append(df.loc[idx, ['X', 'Y']].tolist())
            label = df.loc[0, ['Speed', 'Angle_H', 'Angle_V']].tolist()

            diff = np.diff(np.array(diff), axis=0).tolist()  # compute diff
            for idx, (x, y) in enumerate(diff):
                if x == 0 and y == 0:
                    diff[idx-1] = [0, 0]
            for idx, diff in enumerate(diff):
                data.append(diff)  # diff
                data[idx].append(np.linalg.norm(diff))  # Euclidean distance
            
            x_train = np.expand_dims(data, axis=0)
            y_train = np.expand_dims(np.array(label), axis=0)

            y_train = y_train.astype(np.float32)
            y_train[:, 0] = (y_train[:, 0]-20)/120
            y_train[:, 1] = (y_train[:, 1]-10)/60
            y_train[:, 2] = (y_train[:, 2]-10)/30

            yield x_train, y_train, [None]

# %%
def valid_generator():
    while(True):
        for i, csv in enumerate(valid_list):
            df = pd.read_csv(csv)
            data = []
            diff = []
            for idx in df.index:
                diff.append(df.loc[idx, ['X', 'Y']].tolist())
            label = df.loc[0, ['Speed', 'Angle_H', 'Angle_V']].tolist()

            diff = np.diff(np.array(diff), axis=0).tolist()  # compute diff
            for idx, (x, y) in enumerate(diff):
                if x == 0 and y == 0:
                    diff[idx-1] = [0, 0]
            for idx, diff in enumerate(diff):
                data.append(diff)  # diff
                data[idx].append(np.linalg.norm(diff))  # Euclidean distance
            
            x_valid = np.expand_dims(data, axis=0)
            y_valid = np.expand_dims(np.array(label), axis=0)

            y_valid = y_valid.astype(np.float32)
            y_valid[:, 0] = (y_valid[:, 0]-20)/120
            y_valid[:, 1] = (y_valid[:, 1]-10)/60
            y_valid[:, 2] = (y_valid[:, 2]-10)/30

            yield x_valid, y_valid, [None]

# %%
def test_generator():
    for i, csv in enumerate(test_list):
        df = pd.read_csv(csv)
        data = []
        diff = []
        for idx in df.index:
            diff.append(df.loc[idx, ['X', 'Y']].tolist())
        label = df.loc[0, ['Speed', 'Angle_H', 'Angle_V']].tolist()

        diff = np.diff(np.array(diff), axis=0).tolist()  # compute diff
        for idx, diff in enumerate(diff):
            data.append(diff)  # diff
            data[idx].append(np.linalg.norm(diff))  # Euclidean distance

        x_test = np.expand_dims(data, axis=0)
        y_test = np.expand_dims(np.array(label), axis=0)
#         split_percentage = csv.split('predict_')[1].split('.csv')[0]

        x_test = x_test.astype(np.float32)
        y_test = y_test.astype(np.float32)
        yield x_test, y_test, [None]

# %% [markdown]
# ## Build model

# %%
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
model = Sequential()
model.add(Dense(64, input_shape=(56, 3)))
model.add(ReLU())
model.add(Dropout(0.2))
model.add(Dense(128))
model.add(ReLU())
model.add(Dropout(0.2))
model.add(Dense(64))
model.add(ReLU())
model.add(Dropout(0.2))
model.add(Dense(16))
model.add(ReLU())
model.add(Flatten())
model.add(Dense(16))
model.add(ReLU())
model.add(Dropout(0.2))
model.add(Dense(3))
model.add(ReLU())

model.compile(loss=root_mean_squared_error, optimizer="adam", metrics=['mae'])
model.summary()
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 56, 64)            256
# _________________________________________________________________
# re_lu (ReLU)                 (None, 56, 64)            0
# _________________________________________________________________
# dropout (Dropout)            (None, 56, 64)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 56, 128)           8320
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 56, 128)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 128)           0
# _________________________________________________________________
# dense_2 (Dense)              (None, 56, 64)            8256
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 56, 64)            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 56, 64)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 56, 16)            1040
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 56, 16)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 896)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                14352
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 16)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 51
# _________________________________________________________________
# re_lu_5 (ReLU)               (None, 3)                 0
# =================================================================
# Total params: 32,275
# Trainable params: 32,275
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_file = os.path.join(model_dir, model_name+'.png')
plot_model(model, show_shapes=True, show_layer_names=True, to_file=plot_file)

# %%
# save training logs
model_cbk = keras.callbacks.TensorBoard(log_dir="logs/{}".format(model_name), histogram_freq=1)
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, mode='min')

# save best model weights
model_mckp = keras.callbacks.ModelCheckpoint(os.path.join(model_dir, model_name+".h5"), 
                                             monitor='val_loss', 
                                             save_best_only=True, 
                                             mode='min')

# %%
history = model.fit(train_generator(), 
                    steps_per_epoch=batch_size, 
                    epochs=epochs,
                    validation_data=valid_generator(),
                    validation_steps=len(valid_list),
                    callbacks=[model_mckp, model_cbk])
# Out:
# Epoch 1/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.6266 - mean_absolute_error: 0.5656
# 32/32 [==============================] - 7s 217ms/step - loss: 0.6226 - mean_absolute_error: 0.5534 - val_loss: 0.6266 - val_mean_absolute_error: 0.5656
# Epoch 2/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.6266 - mean_absolute_error: 0.5656
# 32/32 [==============================] - 6s 197ms/step - loss: 0.5977 - mean_absolute_error: 0.5381 - val_loss: 0.6266 - val_mean_absolute_error: 0.5656
# Epoch 3/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.6266 - mean_absolute_error: 0.5656
# 32/32 [==============================] - 7s 204ms/step - loss: 0.6176 - mean_absolute_error: 0.5667 - val_loss: 0.6266 - val_mean_absolute_error: 0.5656
# Epoch 4/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.6266 - mean_absolute_error: 0.5656
# 32/32 [==============================] - 6s 198ms/step - loss: 0.6490 - mean_absolute_error: 0.5798 - val_loss: 0.6266 - val_mean_absolute_error: 0.5656
# Epoch 5/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.5923 - mean_absolute_error: 0.5245
# 32/32 [==============================] - 7s 207ms/step - loss: 0.6051 - mean_absolute_error: 0.5420 - val_loss: 0.5923 - val_mean_absolute_error: 0.5245
# Epoch 6/300
# 83/83 [==============================] - 5s 58ms/step - loss: 0.6112 - mean_absolute_error: 0.5492
# 32/32 [==============================] - 6s 197ms/step - loss: 0.5785 - mean_absolute_error: 0.5213 - val_loss: 0.6112 - val_mean_absolute_error: 0.5492
# Epoch 7/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.6004 - mean_absolute_error: 0.5338
# 32/32 [==============================] - 6s 202ms/step - loss: 0.5975 - mean_absolute_error: 0.5365 - val_loss: 0.6004 - val_mean_absolute_error: 0.5338
# Epoch 8/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.5993 - mean_absolute_error: 0.5335
# 32/32 [==============================] - 6s 201ms/step - loss: 0.6352 - mean_absolute_error: 0.5748 - val_loss: 0.5993 - val_mean_absolute_error: 0.5335
# Epoch 9/300
# 83/83 [==============================] - 5s 65ms/step - loss: 0.6051 - mean_absolute_error: 0.5423
# 32/32 [==============================] - 7s 205ms/step - loss: 0.5664 - mean_absolute_error: 0.5036 - val_loss: 0.6051 - val_mean_absolute_error: 0.5423
# Epoch 10/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.5947 - mean_absolute_error: 0.5258
# 32/32 [==============================] - 6s 200ms/step - loss: 0.6162 - mean_absolute_error: 0.5576 - val_loss: 0.5947 - val_mean_absolute_error: 0.5258
# Epoch 11/300
# 83/83 [==============================] - 5s 65ms/step - loss: 0.6231 - mean_absolute_error: 0.5618
# 32/32 [==============================] - 7s 206ms/step - loss: 0.6204 - mean_absolute_error: 0.5674 - val_loss: 0.6231 - val_mean_absolute_error: 0.5618
# Epoch 12/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.6259 - mean_absolute_error: 0.5650
# 32/32 [==============================] - 6s 194ms/step - loss: 0.5858 - mean_absolute_error: 0.5333 - val_loss: 0.6259 - val_mean_absolute_error: 0.5650
# Epoch 13/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.5971 - mean_absolute_error: 0.5361: 6s - lo
# 32/32 [==============================] - 6s 201ms/step - loss: 0.6679 - mean_absolute_error: 0.6090 - val_loss: 0.5971 - val_mean_absolute_error: 0.5361
# Epoch 14/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.6253 - mean_absolute_error: 0.5645
# 32/32 [==============================] - 6s 203ms/step - loss: 0.7204 - mean_absolute_error: 0.6426 - val_loss: 0.6253 - val_mean_absolute_error: 0.5645
# Epoch 15/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.6165 - mean_absolute_error: 0.5538
# 32/32 [==============================] - 6s 202ms/step - loss: 0.6288 - mean_absolute_error: 0.5637 - val_loss: 0.6165 - val_mean_absolute_error: 0.5538
# Epoch 16/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.6259 - mean_absolute_error: 0.5650: 5s - loss: 0.6369 - mean_absolute_error: 0 - ETA: 4s - loss
# 32/32 [==============================] - 6s 197ms/step - loss: 0.6119 - mean_absolute_error: 0.5591 - val_loss: 0.6259 - val_mean_absolute_error: 0.5650
# Epoch 17/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.6187 - mean_absolute_error: 0.5586: 1s - loss: 0.6072 - mean_absolute
# 32/32 [==============================] - 6s 196ms/step - loss: 0.6634 - mean_absolute_error: 0.5913 - val_loss: 0.6187 - val_mean_absolute_error: 0.5586
# Epoch 18/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.6265 - mean_absolute_error: 0.5655
# 32/32 [==============================] - 6s 196ms/step - loss: 0.6066 - mean_absolute_error: 0.5388 - val_loss: 0.6265 - val_mean_absolute_error: 0.5655
# Epoch 19/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.6263 - mean_absolute_error: 0.5653
# 32/32 [==============================] - 6s 190ms/step - loss: 0.6311 - mean_absolute_error: 0.5568 - val_loss: 0.6263 - val_mean_absolute_error: 0.5653
# Epoch 20/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.6207 - mean_absolute_error: 0.5606
# 32/32 [==============================] - 6s 198ms/step - loss: 0.6434 - mean_absolute_error: 0.5857 - val_loss: 0.6207 - val_mean_absolute_error: 0.5606
# Epoch 21/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.6015 - mean_absolute_error: 0.5417
# 32/32 [==============================] - 7s 203ms/step - loss: 0.6360 - mean_absolute_error: 0.5675 - val_loss: 0.6015 - val_mean_absolute_error: 0.5417
# Epoch 22/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.6100 - mean_absolute_error: 0.5502
# 32/32 [==============================] - 6s 201ms/step - loss: 0.6083 - mean_absolute_error: 0.5646 - val_loss: 0.6100 - val_mean_absolute_error: 0.5502
# Epoch 23/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.4653 - mean_absolute_error: 0.4063
# 32/32 [==============================] - 6s 200ms/step - loss: 0.5362 - mean_absolute_error: 0.4764 - val_loss: 0.4653 - val_mean_absolute_error: 0.4063
# Epoch 24/300
# 83/83 [==============================] - 5s 58ms/step - loss: 0.6124 - mean_absolute_error: 0.5517
# 32/32 [==============================] - 6s 185ms/step - loss: 0.5676 - mean_absolute_error: 0.5070 - val_loss: 0.6124 - val_mean_absolute_error: 0.5517
# Epoch 25/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.4287 - mean_absolute_error: 0.3581
# 32/32 [==============================] - 7s 203ms/step - loss: 0.5291 - mean_absolute_error: 0.4791 - val_loss: 0.4287 - val_mean_absolute_error: 0.3581
# Epoch 26/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.4579 - mean_absolute_error: 0.4003
# 32/32 [==============================] - 6s 192ms/step - loss: 0.4197 - mean_absolute_error: 0.3572 - val_loss: 0.4579 - val_mean_absolute_error: 0.4003
# Epoch 27/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.4079 - mean_absolute_error: 0.3539
# 32/32 [==============================] - 6s 194ms/step - loss: 0.3732 - mean_absolute_error: 0.3210 - val_loss: 0.4079 - val_mean_absolute_error: 0.3539
# Epoch 28/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.2826 - mean_absolute_error: 0.2471
# 32/32 [==============================] - 6s 198ms/step - loss: 0.3487 - mean_absolute_error: 0.3039 - val_loss: 0.2826 - val_mean_absolute_error: 0.2471
# Epoch 29/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.3384 - mean_absolute_error: 0.2930
# 32/32 [==============================] - 6s 198ms/step - loss: 0.3426 - mean_absolute_error: 0.3024 - val_loss: 0.3384 - val_mean_absolute_error: 0.2930
# Epoch 30/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.2537 - mean_absolute_error: 0.2256
# 32/32 [==============================] - 6s 196ms/step - loss: 0.2833 - mean_absolute_error: 0.2431 - val_loss: 0.2537 - val_mean_absolute_error: 0.2256
# Epoch 31/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.2948 - mean_absolute_error: 0.2527
# 32/32 [==============================] - 6s 187ms/step - loss: 0.2498 - mean_absolute_error: 0.2141 - val_loss: 0.2948 - val_mean_absolute_error: 0.2527
# Epoch 32/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.2748 - mean_absolute_error: 0.2321: 0s - loss: 0.2753 - mean_absolute_error: 0.
# 32/32 [==============================] - 6s 197ms/step - loss: 0.2517 - mean_absolute_error: 0.2135 - val_loss: 0.2748 - val_mean_absolute_error: 0.2321
# Epoch 33/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.2424 - mean_absolute_error: 0.2038
# 32/32 [==============================] - 6s 190ms/step - loss: 0.3026 - mean_absolute_error: 0.2684 - val_loss: 0.2424 - val_mean_absolute_error: 0.2038
# Epoch 34/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.2687 - mean_absolute_error: 0.2294
# 32/32 [==============================] - 6s 198ms/step - loss: 0.2508 - mean_absolute_error: 0.2227 - val_loss: 0.2687 - val_mean_absolute_error: 0.2294
# Epoch 35/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.2482 - mean_absolute_error: 0.2165A
# 32/32 [==============================] - 6s 188ms/step - loss: 0.2643 - mean_absolute_error: 0.2264 - val_loss: 0.2482 - val_mean_absolute_error: 0.2165
# Epoch 36/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.2309 - mean_absolute_error: 0.1940
# 32/32 [==============================] - 6s 195ms/step - loss: 0.2647 - mean_absolute_error: 0.2262 - val_loss: 0.2309 - val_mean_absolute_error: 0.1940
# Epoch 37/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.1969 - mean_absolute_error: 0.1709
# 32/32 [==============================] - 7s 204ms/step - loss: 0.2647 - mean_absolute_error: 0.2288 - val_loss: 0.1969 - val_mean_absolute_error: 0.1709
# Epoch 38/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.3214 - mean_absolute_error: 0.2662
# 32/32 [==============================] - 6s 202ms/step - loss: 0.2529 - mean_absolute_error: 0.2130 - val_loss: 0.3214 - val_mean_absolute_error: 0.2662
# Epoch 39/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.2090 - mean_absolute_error: 0.1816
# 32/32 [==============================] - 6s 198ms/step - loss: 0.2568 - mean_absolute_error: 0.2225 - val_loss: 0.2090 - val_mean_absolute_error: 0.1816
# Epoch 40/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.2937 - mean_absolute_error: 0.2607
# 32/32 [==============================] - 6s 195ms/step - loss: 0.3342 - mean_absolute_error: 0.3002 - val_loss: 0.2937 - val_mean_absolute_error: 0.2607
# Epoch 41/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.2232 - mean_absolute_error: 0.1931
# 32/32 [==============================] - 6s 191ms/step - loss: 0.2400 - mean_absolute_error: 0.2048 - val_loss: 0.2232 - val_mean_absolute_error: 0.1931
# Epoch 42/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.1934 - mean_absolute_error: 0.1671
# 32/32 [==============================] - 6s 197ms/step - loss: 0.2414 - mean_absolute_error: 0.2116 - val_loss: 0.1934 - val_mean_absolute_error: 0.1671
# Epoch 43/300
# 83/83 [==============================] - 5s 58ms/step - loss: 0.2324 - mean_absolute_error: 0.2032
# 32/32 [==============================] - 6s 188ms/step - loss: 0.2287 - mean_absolute_error: 0.2014 - val_loss: 0.2324 - val_mean_absolute_error: 0.2032
# Epoch 44/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.2123 - mean_absolute_error: 0.1852
# 32/32 [==============================] - 6s 193ms/step - loss: 0.2332 - mean_absolute_error: 0.1950 - val_loss: 0.2123 - val_mean_absolute_error: 0.1852
# Epoch 45/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1966 - mean_absolute_error: 0.1671
# 32/32 [==============================] - 6s 193ms/step - loss: 0.2472 - mean_absolute_error: 0.2093 - val_loss: 0.1966 - val_mean_absolute_error: 0.1671
# Epoch 46/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1931 - mean_absolute_error: 0.1651
# 32/32 [==============================] - 6s 195ms/step - loss: 0.2362 - mean_absolute_error: 0.1994 - val_loss: 0.1931 - val_mean_absolute_error: 0.1651
# Epoch 47/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.2015 - mean_absolute_error: 0.1753
# 32/32 [==============================] - 6s 194ms/step - loss: 0.2092 - mean_absolute_error: 0.1794 - val_loss: 0.2015 - val_mean_absolute_error: 0.1753
# Epoch 48/300
# 83/83 [==============================] - 5s 58ms/step - loss: 0.2175 - mean_absolute_error: 0.1873
# 32/32 [==============================] - 6s 187ms/step - loss: 0.2502 - mean_absolute_error: 0.2207 - val_loss: 0.2175 - val_mean_absolute_error: 0.1873
# Epoch 49/300
# 83/83 [==============================] - 5s 58ms/step - loss: 0.1870 - mean_absolute_error: 0.1601: 2s - loss: 0.1818 - mean_a
# 32/32 [==============================] - 6s 188ms/step - loss: 0.2557 - mean_absolute_error: 0.2214 - val_loss: 0.1870 - val_mean_absolute_error: 0.1601
# Epoch 50/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.1879 - mean_absolute_error: 0.1521
# 32/32 [==============================] - 6s 192ms/step - loss: 0.1944 - mean_absolute_error: 0.1641 - val_loss: 0.1879 - val_mean_absolute_error: 0.1521
# Epoch 51/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.1922 - mean_absolute_error: 0.1629
# 32/32 [==============================] - 6s 190ms/step - loss: 0.2191 - mean_absolute_error: 0.1876 - val_loss: 0.1922 - val_mean_absolute_error: 0.1629
# Epoch 52/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.2008 - mean_absolute_error: 0.1753: 2s - loss: 0.2025 - mean_
# 32/32 [==============================] - 6s 192ms/step - loss: 0.1979 - mean_absolute_error: 0.1717 - val_loss: 0.2008 - val_mean_absolute_error: 0.1753
# Epoch 53/300
# 83/83 [==============================] - 5s 57ms/step - loss: 0.2094 - mean_absolute_error: 0.1790
# 32/32 [==============================] - 6s 182ms/step - loss: 0.2242 - mean_absolute_error: 0.1913 - val_loss: 0.2094 - val_mean_absolute_error: 0.1790
# Epoch 54/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.2169 - mean_absolute_error: 0.1888: 2s - loss: 0.2248 -
# 32/32 [==============================] - 6s 198ms/step - loss: 0.2109 - mean_absolute_error: 0.1832 - val_loss: 0.2169 - val_mean_absolute_error: 0.1888
# Epoch 55/300
# 83/83 [==============================] - 5s 64ms/step - loss: 0.2011 - mean_absolute_error: 0.1756: 4s -
# 32/32 [==============================] - 6s 201ms/step - loss: 0.2167 - mean_absolute_error: 0.1927 - val_loss: 0.2011 - val_mean_absolute_error: 0.1756
# Epoch 56/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.1985 - mean_absolute_error: 0.1711
# 32/32 [==============================] - 6s 197ms/step - loss: 0.2065 - mean_absolute_error: 0.1781 - val_loss: 0.1985 - val_mean_absolute_error: 0.1711
# Epoch 57/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.2141 - mean_absolute_error: 0.1869
# 32/32 [==============================] - 7s 204ms/step - loss: 0.2006 - mean_absolute_error: 0.1743 - val_loss: 0.2141 - val_mean_absolute_error: 0.1869
# Epoch 58/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.2485 - mean_absolute_error: 0.2143
# 32/32 [==============================] - 6s 194ms/step - loss: 0.2553 - mean_absolute_error: 0.2242 - val_loss: 0.2485 - val_mean_absolute_error: 0.2143
# Epoch 59/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1872 - mean_absolute_error: 0.1621: 4s - loss:
# 32/32 [==============================] - 6s 197ms/step - loss: 0.2225 - mean_absolute_error: 0.1890 - val_loss: 0.1872 - val_mean_absolute_error: 0.1621
# Epoch 60/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.2070 - mean_absolute_error: 0.1796
# 32/32 [==============================] - 6s 192ms/step - loss: 0.1986 - mean_absolute_error: 0.1712 - val_loss: 0.2070 - val_mean_absolute_error: 0.1796
# Epoch 61/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.2064 - mean_absolute_error: 0.1770
# 32/32 [==============================] - 6s 191ms/step - loss: 0.2469 - mean_absolute_error: 0.2230 - val_loss: 0.2064 - val_mean_absolute_error: 0.1770
# Epoch 62/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.1794 - mean_absolute_error: 0.1530
# 32/32 [==============================] - 6s 201ms/step - loss: 0.2144 - mean_absolute_error: 0.1846 - val_loss: 0.1794 - val_mean_absolute_error: 0.1530
# Epoch 63/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.1955 - mean_absolute_error: 0.1651
# 32/32 [==============================] - 6s 198ms/step - loss: 0.1894 - mean_absolute_error: 0.1632 - val_loss: 0.1955 - val_mean_absolute_error: 0.1651
# Epoch 64/300
# 83/83 [==============================] - 5s 64ms/step - loss: 0.1810 - mean_absolute_error: 0.1572
# 32/32 [==============================] - 7s 203ms/step - loss: 0.1925 - mean_absolute_error: 0.1670 - val_loss: 0.1810 - val_mean_absolute_error: 0.1572
# Epoch 65/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.1814 - mean_absolute_error: 0.1540
# 32/32 [==============================] - 6s 196ms/step - loss: 0.2242 - mean_absolute_error: 0.1900 - val_loss: 0.1814 - val_mean_absolute_error: 0.1540
# Epoch 66/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1793 - mean_absolute_error: 0.1532
# 32/32 [==============================] - 6s 194ms/step - loss: 0.1836 - mean_absolute_error: 0.1575 - val_loss: 0.1793 - val_mean_absolute_error: 0.1532
# Epoch 67/300
# 83/83 [==============================] - 5s 57ms/step - loss: 0.1746 - mean_absolute_error: 0.1484
# 32/32 [==============================] - 6s 186ms/step - loss: 0.2062 - mean_absolute_error: 0.1741 - val_loss: 0.1746 - val_mean_absolute_error: 0.1484
# Epoch 68/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.1786 - mean_absolute_error: 0.1512
# 32/32 [==============================] - 6s 196ms/step - loss: 0.2080 - mean_absolute_error: 0.1775 - val_loss: 0.1786 - val_mean_absolute_error: 0.1512
# Epoch 69/300
# 83/83 [==============================] - 5s 58ms/step - loss: 0.1750 - mean_absolute_error: 0.1458
# 32/32 [==============================] - 6s 189ms/step - loss: 0.2022 - mean_absolute_error: 0.1714 - val_loss: 0.1750 - val_mean_absolute_error: 0.1458
# Epoch 70/300
# 83/83 [==============================] - 4s 49ms/step - loss: 0.2013 - mean_absolute_error: 0.1707
# 32/32 [==============================] - 6s 177ms/step - loss: 0.2035 - mean_absolute_error: 0.1728 - val_loss: 0.2013 - val_mean_absolute_error: 0.1707
# Epoch 71/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.1867 - mean_absolute_error: 0.1580
# 32/32 [==============================] - 6s 199ms/step - loss: 0.2155 - mean_absolute_error: 0.1893 - val_loss: 0.1867 - val_mean_absolute_error: 0.1580
# Epoch 72/300
# 83/83 [==============================] - 5s 64ms/step - loss: 0.1909 - mean_absolute_error: 0.1642
# 32/32 [==============================] - 6s 203ms/step - loss: 0.1967 - mean_absolute_error: 0.1630 - val_loss: 0.1909 - val_mean_absolute_error: 0.1642
# Epoch 73/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1748 - mean_absolute_error: 0.1478
# 32/32 [==============================] - 6s 193ms/step - loss: 0.1947 - mean_absolute_error: 0.1652 - val_loss: 0.1748 - val_mean_absolute_error: 0.1478
# Epoch 74/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1773 - mean_absolute_error: 0.1512
# 32/32 [==============================] - 6s 190ms/step - loss: 0.1925 - mean_absolute_error: 0.1624 - val_loss: 0.1773 - val_mean_absolute_error: 0.1512
# Epoch 75/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1931 - mean_absolute_error: 0.1611: 2s - loss: 0.2064 - m
# 32/32 [==============================] - 6s 195ms/step - loss: 0.2018 - mean_absolute_error: 0.1685 - val_loss: 0.1931 - val_mean_absolute_error: 0.1611
# Epoch 76/300
# 83/83 [==============================] - 4s 52ms/step - loss: 0.1840 - mean_absolute_error: 0.1547
# 32/32 [==============================] - 6s 186ms/step - loss: 0.2081 - mean_absolute_error: 0.1791 - val_loss: 0.1840 - val_mean_absolute_error: 0.1547
# Epoch 77/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.1837 - mean_absolute_error: 0.1560
# 32/32 [==============================] - 6s 197ms/step - loss: 0.2149 - mean_absolute_error: 0.1867 - val_loss: 0.1837 - val_mean_absolute_error: 0.1560
# Epoch 78/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.1797 - mean_absolute_error: 0.1509
# 32/32 [==============================] - 6s 187ms/step - loss: 0.1831 - mean_absolute_error: 0.1585 - val_loss: 0.1797 - val_mean_absolute_error: 0.1509
# Epoch 79/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.1839 - mean_absolute_error: 0.1568: 5s - l
# 32/32 [==============================] - 6s 203ms/step - loss: 0.2003 - mean_absolute_error: 0.1594 - val_loss: 0.1839 - val_mean_absolute_error: 0.1568
# Epoch 80/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1868 - mean_absolute_error: 0.1591
# 32/32 [==============================] - 6s 194ms/step - loss: 0.1995 - mean_absolute_error: 0.1718 - val_loss: 0.1868 - val_mean_absolute_error: 0.1591
# Epoch 81/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.2020 - mean_absolute_error: 0.1735
# 32/32 [==============================] - 6s 200ms/step - loss: 0.2012 - mean_absolute_error: 0.1725 - val_loss: 0.2020 - val_mean_absolute_error: 0.1735
# Epoch 82/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1760 - mean_absolute_error: 0.1454
# 32/32 [==============================] - 6s 191ms/step - loss: 0.2154 - mean_absolute_error: 0.1817 - val_loss: 0.1760 - val_mean_absolute_error: 0.1454
# Epoch 83/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.1756 - mean_absolute_error: 0.1473
# 32/32 [==============================] - 6s 190ms/step - loss: 0.2049 - mean_absolute_error: 0.1735 - val_loss: 0.1756 - val_mean_absolute_error: 0.1473
# Epoch 84/300
# 83/83 [==============================] - 5s 57ms/step - loss: 0.1829 - mean_absolute_error: 0.1542: 8s - loss: 0.2266 - mean_absolute_error: 0.188 - ETA: 9
# 32/32 [==============================] - 6s 188ms/step - loss: 0.1849 - mean_absolute_error: 0.1551 - val_loss: 0.1829 - val_mean_absolute_error: 0.1542
# Epoch 85/300
# 83/83 [==============================] - 5s 58ms/step - loss: 0.1769 - mean_absolute_error: 0.1488: 1s - loss: 0.1799 - mean_absolu
# 32/32 [==============================] - 6s 186ms/step - loss: 0.1936 - mean_absolute_error: 0.1656 - val_loss: 0.1769 - val_mean_absolute_error: 0.1488
# Epoch 86/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.1787 - mean_absolute_error: 0.1521
# 32/32 [==============================] - 6s 198ms/step - loss: 0.1793 - mean_absolute_error: 0.1512 - val_loss: 0.1787 - val_mean_absolute_error: 0.1521
# Epoch 87/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.1769 - mean_absolute_error: 0.1521
# 32/32 [==============================] - 6s 195ms/step - loss: 0.1993 - mean_absolute_error: 0.1694 - val_loss: 0.1769 - val_mean_absolute_error: 0.1521
# Epoch 88/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.1871 - mean_absolute_error: 0.1573
# 32/32 [==============================] - 6s 191ms/step - loss: 0.1746 - mean_absolute_error: 0.1484 - val_loss: 0.1871 - val_mean_absolute_error: 0.1573
# Epoch 89/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1790 - mean_absolute_error: 0.1561
# 32/32 [==============================] - 6s 195ms/step - loss: 0.2163 - mean_absolute_error: 0.1896 - val_loss: 0.1790 - val_mean_absolute_error: 0.1561
# Epoch 90/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.1789 - mean_absolute_error: 0.1531
# 32/32 [==============================] - 6s 196ms/step - loss: 0.1984 - mean_absolute_error: 0.1725 - val_loss: 0.1789 - val_mean_absolute_error: 0.1531
# Epoch 91/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1816 - mean_absolute_error: 0.1569
# 32/32 [==============================] - 6s 194ms/step - loss: 0.1713 - mean_absolute_error: 0.1468 - val_loss: 0.1816 - val_mean_absolute_error: 0.1569
# Epoch 92/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.1933 - mean_absolute_error: 0.1644
# 32/32 [==============================] - 6s 196ms/step - loss: 0.1956 - mean_absolute_error: 0.1677 - val_loss: 0.1933 - val_mean_absolute_error: 0.1644
# Epoch 93/300
# 83/83 [==============================] - 5s 56ms/step - loss: 0.1793 - mean_absolute_error: 0.1519
# 32/32 [==============================] - 6s 183ms/step - loss: 0.1780 - mean_absolute_error: 0.1556 - val_loss: 0.1793 - val_mean_absolute_error: 0.1519
# Epoch 94/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.1932 - mean_absolute_error: 0.1651
# 32/32 [==============================] - 6s 196ms/step - loss: 0.1963 - mean_absolute_error: 0.1644 - val_loss: 0.1932 - val_mean_absolute_error: 0.1651
# Epoch 95/300
# 83/83 [==============================] - 4s 50ms/step - loss: 0.1917 - mean_absolute_error: 0.1639
# 32/32 [==============================] - 6s 179ms/step - loss: 0.1965 - mean_absolute_error: 0.1669 - val_loss: 0.1917 - val_mean_absolute_error: 0.1639
# Epoch 96/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.1865 - mean_absolute_error: 0.1597
# 32/32 [==============================] - 6s 195ms/step - loss: 0.1980 - mean_absolute_error: 0.1732 - val_loss: 0.1865 - val_mean_absolute_error: 0.1597
# Epoch 97/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.1777 - mean_absolute_error: 0.1512
# 32/32 [==============================] - 6s 198ms/step - loss: 0.2052 - mean_absolute_error: 0.1764 - val_loss: 0.1777 - val_mean_absolute_error: 0.1512
# Epoch 98/300
# 83/83 [==============================] - 5s 57ms/step - loss: 0.1790 - mean_absolute_error: 0.1538
# 32/32 [==============================] - 6s 185ms/step - loss: 0.1836 - mean_absolute_error: 0.1626 - val_loss: 0.1790 - val_mean_absolute_error: 0.1538
# Epoch 99/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.1808 - mean_absolute_error: 0.1549
# 32/32 [==============================] - 6s 200ms/step - loss: 0.1659 - mean_absolute_error: 0.1416 - val_loss: 0.1808 - val_mean_absolute_error: 0.1549
# Epoch 100/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1766 - mean_absolute_error: 0.1507
# 32/32 [==============================] - 6s 191ms/step - loss: 0.1784 - mean_absolute_error: 0.1501 - val_loss: 0.1766 - val_mean_absolute_error: 0.1507
# Epoch 101/300
# 83/83 [==============================] - 5s 55ms/step - loss: 0.1830 - mean_absolute_error: 0.1582
# 32/32 [==============================] - 6s 189ms/step - loss: 0.2082 - mean_absolute_error: 0.1816 - val_loss: 0.1830 - val_mean_absolute_error: 0.1582
# Epoch 102/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1818 - mean_absolute_error: 0.1575
# 32/32 [==============================] - 6s 194ms/step - loss: 0.1891 - mean_absolute_error: 0.1675 - val_loss: 0.1818 - val_mean_absolute_error: 0.1575
# Epoch 103/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.1770 - mean_absolute_error: 0.1519
# 32/32 [==============================] - 6s 199ms/step - loss: 0.1840 - mean_absolute_error: 0.1539 - val_loss: 0.1770 - val_mean_absolute_error: 0.1519
# Epoch 104/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.1868 - mean_absolute_error: 0.1612
# 32/32 [==============================] - 6s 193ms/step - loss: 0.1880 - mean_absolute_error: 0.1596 - val_loss: 0.1868 - val_mean_absolute_error: 0.1612
# Epoch 105/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.1858 - mean_absolute_error: 0.1603: 2s - loss: 0.1706 -
# 32/32 [==============================] - 6s 198ms/step - loss: 0.1755 - mean_absolute_error: 0.1519 - val_loss: 0.1858 - val_mean_absolute_error: 0.1603
# Epoch 106/300
# 83/83 [==============================] - 6s 67ms/step - loss: 0.1823 - mean_absolute_error: 0.1556
# 32/32 [==============================] - 7s 212ms/step - loss: 0.1955 - mean_absolute_error: 0.1717 - val_loss: 0.1823 - val_mean_absolute_error: 0.1556
# Epoch 107/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1826 - mean_absolute_error: 0.1544
# 32/32 [==============================] - 7s 208ms/step - loss: 0.1803 - mean_absolute_error: 0.1544 - val_loss: 0.1826 - val_mean_absolute_error: 0.1544
# Epoch 108/300
# 83/83 [==============================] - 5s 65ms/step - loss: 0.1757 - mean_absolute_error: 0.1494
# 32/32 [==============================] - 7s 209ms/step - loss: 0.2022 - mean_absolute_error: 0.1732 - val_loss: 0.1757 - val_mean_absolute_error: 0.1494
# Epoch 109/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.1873 - mean_absolute_error: 0.1617: 2s - loss: 0.1806 - mean_a
# 32/32 [==============================] - 7s 205ms/step - loss: 0.1871 - mean_absolute_error: 0.1623 - val_loss: 0.1873 - val_mean_absolute_error: 0.1617
# Epoch 110/300
# 83/83 [==============================] - 5s 64ms/step - loss: 0.1786 - mean_absolute_error: 0.1533
# 32/32 [==============================] - 7s 205ms/step - loss: 0.2024 - mean_absolute_error: 0.1690 - val_loss: 0.1786 - val_mean_absolute_error: 0.1533
# Epoch 111/300
# 83/83 [==============================] - 5s 64ms/step - loss: 0.1708 - mean_absolute_error: 0.1417
# 32/32 [==============================] - 7s 210ms/step - loss: 0.1529 - mean_absolute_error: 0.1270 - val_loss: 0.1708 - val_mean_absolute_error: 0.1417
# Epoch 112/300
# 83/83 [==============================] - 5s 66ms/step - loss: 0.1793 - mean_absolute_error: 0.1524
# 32/32 [==============================] - 7s 214ms/step - loss: 0.1848 - mean_absolute_error: 0.1599 - val_loss: 0.1793 - val_mean_absolute_error: 0.1524
# Epoch 113/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.1856 - mean_absolute_error: 0.1588
# 32/32 [==============================] - 6s 195ms/step - loss: 0.1929 - mean_absolute_error: 0.1628 - val_loss: 0.1856 - val_mean_absolute_error: 0.1588
# Epoch 114/300
# 83/83 [==============================] - 5s 66ms/step - loss: 0.1705 - mean_absolute_error: 0.1429
# 32/32 [==============================] - 7s 213ms/step - loss: 0.1996 - mean_absolute_error: 0.1726 - val_loss: 0.1705 - val_mean_absolute_error: 0.1429
# Epoch 115/300
# 83/83 [==============================] - 6s 67ms/step - loss: 0.1783 - mean_absolute_error: 0.1509: 5
# 32/32 [==============================] - 7s 211ms/step - loss: 0.2219 - mean_absolute_error: 0.1839 - val_loss: 0.1783 - val_mean_absolute_error: 0.1509
# Epoch 116/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.1768 - mean_absolute_error: 0.1497
# 32/32 [==============================] - 6s 202ms/step - loss: 0.1717 - mean_absolute_error: 0.1381 - val_loss: 0.1768 - val_mean_absolute_error: 0.1497
# Epoch 117/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.1751 - mean_absolute_error: 0.1475
# 32/32 [==============================] - 6s 200ms/step - loss: 0.1870 - mean_absolute_error: 0.1539 - val_loss: 0.1751 - val_mean_absolute_error: 0.1475
# Epoch 118/300
# 83/83 [==============================] - 6s 68ms/step - loss: 0.1818 - mean_absolute_error: 0.1553
# 32/32 [==============================] - 7s 222ms/step - loss: 0.2009 - mean_absolute_error: 0.1686 - val_loss: 0.1818 - val_mean_absolute_error: 0.1553
# Epoch 119/300
# 83/83 [==============================] - 5s 66ms/step - loss: 0.1830 - mean_absolute_error: 0.1565
# 32/32 [==============================] - 7s 211ms/step - loss: 0.1902 - mean_absolute_error: 0.1573 - val_loss: 0.1830 - val_mean_absolute_error: 0.1565
# Epoch 120/300
# 83/83 [==============================] - 5s 66ms/step - loss: 0.1828 - mean_absolute_error: 0.1573
# 32/32 [==============================] - 7s 213ms/step - loss: 0.2373 - mean_absolute_error: 0.1965 - val_loss: 0.1828 - val_mean_absolute_error: 0.1573
# Epoch 121/300
# 83/83 [==============================] - 6s 67ms/step - loss: 0.1929 - mean_absolute_error: 0.1661: 4s - los
# 32/32 [==============================] - 7s 217ms/step - loss: 0.1615 - mean_absolute_error: 0.1419 - val_loss: 0.1929 - val_mean_absolute_error: 0.1661
# Epoch 122/300
# 83/83 [==============================] - 5s 65ms/step - loss: 0.1862 - mean_absolute_error: 0.1606
# 32/32 [==============================] - 7s 211ms/step - loss: 0.1958 - mean_absolute_error: 0.1640 - val_loss: 0.1862 - val_mean_absolute_error: 0.1606
# Epoch 123/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1761 - mean_absolute_error: 0.1505
# 32/32 [==============================] - 7s 206ms/step - loss: 0.1861 - mean_absolute_error: 0.1600 - val_loss: 0.1761 - val_mean_absolute_error: 0.1505
# Epoch 124/300
# 83/83 [==============================] - 5s 65ms/step - loss: 0.1804 - mean_absolute_error: 0.1550
# 32/32 [==============================] - 7s 225ms/step - loss: 0.1747 - mean_absolute_error: 0.1428 - val_loss: 0.1804 - val_mean_absolute_error: 0.1550
# Epoch 125/300
# 83/83 [==============================] - 6s 71ms/step - loss: 0.1929 - mean_absolute_error: 0.1670
# 32/32 [==============================] - 7s 229ms/step - loss: 0.1866 - mean_absolute_error: 0.1531 - val_loss: 0.1929 - val_mean_absolute_error: 0.1670
# Epoch 126/300
# 83/83 [==============================] - 5s 65ms/step - loss: 0.1756 - mean_absolute_error: 0.1505
# 32/32 [==============================] - 7s 212ms/step - loss: 0.1774 - mean_absolute_error: 0.1522 - val_loss: 0.1756 - val_mean_absolute_error: 0.1505
# Epoch 127/300
# 83/83 [==============================] - 5s 66ms/step - loss: 0.1788 - mean_absolute_error: 0.1533: 0s - loss: 0.1842 - mean_absolute_err
# 32/32 [==============================] - 7s 212ms/step - loss: 0.2063 - mean_absolute_error: 0.1763 - val_loss: 0.1788 - val_mean_absolute_error: 0.1533
# Epoch 128/300
# 83/83 [==============================] - 5s 64ms/step - loss: 0.1842 - mean_absolute_error: 0.1585
# 32/32 [==============================] - 7s 209ms/step - loss: 0.1836 - mean_absolute_error: 0.1563 - val_loss: 0.1842 - val_mean_absolute_error: 0.1585
# Epoch 129/300
# 83/83 [==============================] - 5s 57ms/step - loss: 0.1960 - mean_absolute_error: 0.1684
# 32/32 [==============================] - 6s 200ms/step - loss: 0.1708 - mean_absolute_error: 0.1464 - val_loss: 0.1960 - val_mean_absolute_error: 0.1684
# Epoch 130/300
# 83/83 [==============================] - 5s 65ms/step - loss: 0.1805 - mean_absolute_error: 0.1549: 5s - loss: 0.1933 - mean_absolute_error: 0.162 - ETA: 4s - l
# 32/32 [==============================] - 7s 212ms/step - loss: 0.1996 - mean_absolute_error: 0.1686 - val_loss: 0.1805 - val_mean_absolute_error: 0.1549
# Epoch 131/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.1778 - mean_absolute_error: 0.1523
# 32/32 [==============================] - 7s 209ms/step - loss: 0.1770 - mean_absolute_error: 0.1460 - val_loss: 0.1778 - val_mean_absolute_error: 0.1523
# Epoch 132/300
# 83/83 [==============================] - 5s 64ms/step - loss: 0.1757 - mean_absolute_error: 0.1518
# 32/32 [==============================] - 7s 208ms/step - loss: 0.1854 - mean_absolute_error: 0.1506 - val_loss: 0.1757 - val_mean_absolute_error: 0.1518
# Epoch 133/300
# 83/83 [==============================] - 6s 67ms/step - loss: 0.1791 - mean_absolute_error: 0.1555
# 32/32 [==============================] - 7s 218ms/step - loss: 0.1772 - mean_absolute_error: 0.1445 - val_loss: 0.1791 - val_mean_absolute_error: 0.1555
# Epoch 134/300
# 83/83 [==============================] - 5s 66ms/step - loss: 0.1732 - mean_absolute_error: 0.1451: 0s - loss: 0.1752 - mean_absolute_error: 0.14
# 32/32 [==============================] - 7s 212ms/step - loss: 0.1927 - mean_absolute_error: 0.1652 - val_loss: 0.1732 - val_mean_absolute_error: 0.1451
# Epoch 135/300
# 83/83 [==============================] - 5s 65ms/step - loss: 0.1792 - mean_absolute_error: 0.1533: 7
# 32/32 [==============================] - 7s 208ms/step - loss: 0.1982 - mean_absolute_error: 0.1693 - val_loss: 0.1792 - val_mean_absolute_error: 0.1533
# Epoch 136/300
# 83/83 [==============================] - 4s 50ms/step - loss: 0.1773 - mean_absolute_error: 0.1520
# 32/32 [==============================] - 6s 181ms/step - loss: 0.1748 - mean_absolute_error: 0.1487 - val_loss: 0.1773 - val_mean_absolute_error: 0.1520
# Epoch 137/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1768 - mean_absolute_error: 0.1497
# 32/32 [==============================] - 6s 195ms/step - loss: 0.1653 - mean_absolute_error: 0.1409 - val_loss: 0.1768 - val_mean_absolute_error: 0.1497
# Epoch 138/300
# 83/83 [==============================] - 5s 57ms/step - loss: 0.1743 - mean_absolute_error: 0.1485
# 32/32 [==============================] - 7s 207ms/step - loss: 0.1789 - mean_absolute_error: 0.1465 - val_loss: 0.1743 - val_mean_absolute_error: 0.1485
# Epoch 139/300
# 83/83 [==============================] - 5s 57ms/step - loss: 0.1894 - mean_absolute_error: 0.1637
# 32/32 [==============================] - 6s 197ms/step - loss: 0.2079 - mean_absolute_error: 0.1712 - val_loss: 0.1894 - val_mean_absolute_error: 0.1637
# Epoch 140/300
# 83/83 [==============================] - 4s 54ms/step - loss: 0.1815 - mean_absolute_error: 0.1558: 2s - loss: 0.1948 - mean
# 32/32 [==============================] - 6s 189ms/step - loss: 0.1958 - mean_absolute_error: 0.1720 - val_loss: 0.1815 - val_mean_absolute_error: 0.1558
# Epoch 141/300
# 83/83 [==============================] - 4s 49ms/step - loss: 0.1740 - mean_absolute_error: 0.1487
# 32/32 [==============================] - 6s 180ms/step - loss: 0.1954 - mean_absolute_error: 0.1751 - val_loss: 0.1740 - val_mean_absolute_error: 0.1487
# Epoch 142/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1828 - mean_absolute_error: 0.1581: 1s - loss: 0.1834 - mean_absolute_er
# 32/32 [==============================] - 6s 192ms/step - loss: 0.1824 - mean_absolute_error: 0.1557 - val_loss: 0.1828 - val_mean_absolute_error: 0.1581
# Epoch 143/300
# 83/83 [==============================] - 5s 57ms/step - loss: 0.1861 - mean_absolute_error: 0.1603
# 32/32 [==============================] - 6s 189ms/step - loss: 0.1650 - mean_absolute_error: 0.1439 - val_loss: 0.1861 - val_mean_absolute_error: 0.1603
# Epoch 144/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.1843 - mean_absolute_error: 0.1586
# 32/32 [==============================] - 6s 191ms/step - loss: 0.2075 - mean_absolute_error: 0.1778 - val_loss: 0.1843 - val_mean_absolute_error: 0.1586
# Epoch 145/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.1793 - mean_absolute_error: 0.1528
# 32/32 [==============================] - 6s 192ms/step - loss: 0.2038 - mean_absolute_error: 0.1735 - val_loss: 0.1793 - val_mean_absolute_error: 0.1528
# Epoch 146/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.1751 - mean_absolute_error: 0.1494
# 32/32 [==============================] - 6s 199ms/step - loss: 0.1976 - mean_absolute_error: 0.1635 - val_loss: 0.1751 - val_mean_absolute_error: 0.1494
# Epoch 147/300
# 83/83 [==============================] - 5s 57ms/step - loss: 0.1816 - mean_absolute_error: 0.1554
# 32/32 [==============================] - 6s 191ms/step - loss: 0.1684 - mean_absolute_error: 0.1423 - val_loss: 0.1816 - val_mean_absolute_error: 0.1554
# Epoch 148/300
# 83/83 [==============================] - 5s 62ms/step - loss: 0.1841 - mean_absolute_error: 0.1568
# 32/32 [==============================] - 7s 204ms/step - loss: 0.1813 - mean_absolute_error: 0.1469 - val_loss: 0.1841 - val_mean_absolute_error: 0.1568
# Epoch 149/300
# 83/83 [==============================] - 4s 54ms/step - loss: 0.1781 - mean_absolute_error: 0.1524
# 32/32 [==============================] - 6s 187ms/step - loss: 0.2030 - mean_absolute_error: 0.1745 - val_loss: 0.1781 - val_mean_absolute_error: 0.1524
# Epoch 150/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.1825 - mean_absolute_error: 0.1574: 4s - loss
# 32/32 [==============================] - 6s 189ms/step - loss: 0.1894 - mean_absolute_error: 0.1596 - val_loss: 0.1825 - val_mean_absolute_error: 0.1574
# Epoch 151/300
# 83/83 [==============================] - 5s 58ms/step - loss: 0.1693 - mean_absolute_error: 0.1413
# 32/32 [==============================] - 6s 188ms/step - loss: 0.2093 - mean_absolute_error: 0.1760 - val_loss: 0.1693 - val_mean_absolute_error: 0.1413
# Epoch 152/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.1816 - mean_absolute_error: 0.1573
# 32/32 [==============================] - 6s 199ms/step - loss: 0.1839 - mean_absolute_error: 0.1521 - val_loss: 0.1816 - val_mean_absolute_error: 0.1573
# Epoch 153/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.1733 - mean_absolute_error: 0.1473
# 32/32 [==============================] - 6s 199ms/step - loss: 0.1652 - mean_absolute_error: 0.1408 - val_loss: 0.1733 - val_mean_absolute_error: 0.1473
# Epoch 154/300
# 83/83 [==============================] - 5s 61ms/step - loss: 0.1713 - mean_absolute_error: 0.1441
# 32/32 [==============================] - 6s 193ms/step - loss: 0.2028 - mean_absolute_error: 0.1729 - val_loss: 0.1713 - val_mean_absolute_error: 0.1441
# Epoch 155/300
# 83/83 [==============================] - 6s 66ms/step - loss: 0.1737 - mean_absolute_error: 0.1474
# 32/32 [==============================] - 7s 211ms/step - loss: 0.1828 - mean_absolute_error: 0.1489 - val_loss: 0.1737 - val_mean_absolute_error: 0.1474
# Epoch 156/300
# 83/83 [==============================] - 5s 64ms/step - loss: 0.1945 - mean_absolute_error: 0.1652
# 32/32 [==============================] - 6s 203ms/step - loss: 0.1916 - mean_absolute_error: 0.1654 - val_loss: 0.1945 - val_mean_absolute_error: 0.1652
# Epoch 157/300
# 83/83 [==============================] - 6s 67ms/step - loss: 0.1717 - mean_absolute_error: 0.1458
# 32/32 [==============================] - 7s 211ms/step - loss: 0.1682 - mean_absolute_error: 0.1399 - val_loss: 0.1717 - val_mean_absolute_error: 0.1458
# Epoch 158/300
# 83/83 [==============================] - 5s 60ms/step - loss: 0.1771 - mean_absolute_error: 0.1521
# 32/32 [==============================] - 6s 202ms/step - loss: 0.1841 - mean_absolute_error: 0.1495 - val_loss: 0.1771 - val_mean_absolute_error: 0.1521
# Epoch 159/300
# 83/83 [==============================] - 5s 59ms/step - loss: 0.1845 - mean_absolute_error: 0.1592
# 32/32 [==============================] - 6s 192ms/step - loss: 0.1917 - mean_absolute_error: 0.1636 - val_loss: 0.1845 - val_mean_absolute_error: 0.1592
# Epoch 160/300
# 83/83 [==============================] - 5s 63ms/step - loss: 0.1757 - mean_absolute_error: 0.1499
# 32/32 [==============================] - 6s 198ms/step - loss: 0.1827 - mean_absolute_error: 0.1533 - val_loss: 0.1757 - val_mean_absolute_error: 0.1499
# Epoch 161/300
# 83/83 [==============================] - 5s 66ms/step - loss: 0.1804 - mean_absolute_error: 0.1479
# 32/32 [==============================] - 7s 215ms/step - loss: 0.1846 - mean_absolute_error: 0.1542 - val_loss: 0.1804 - val_mean_absolute_error: 0.1479
# Epoch 162/300
# 83/83 [==============================] - 7s 87ms/step - loss: 0.1761 - mean_absolute_error: 0.1506
# 32/32 [==============================] - 9s 278ms/step - loss: 0.1735 - mean_absolute_error: 0.1454 - val_loss: 0.1761 - val_mean_absolute_error: 0.1506
# Epoch 163/300
# 83/83 [==============================] - 7s 85ms/step - loss: 0.1791 - mean_absolute_error: 0.1542
# 32/32 [==============================] - 9s 268ms/step - loss: 0.1801 - mean_absolute_error: 0.1515 - val_loss: 0.1791 - val_mean_absolute_error: 0.1542
# Epoch 164/300
# 83/83 [==============================] - 7s 89ms/step - loss: 0.1760 - mean_absolute_error: 0.1500
# 32/32 [==============================] - 9s 285ms/step - loss: 0.1784 - mean_absolute_error: 0.1499 - val_loss: 0.1760 - val_mean_absolute_error: 0.1500
# Epoch 165/300
# 83/83 [==============================] - 7s 90ms/step - loss: 0.1779 - mean_absolute_error: 0.1514
# 32/32 [==============================] - 9s 287ms/step - loss: 0.1675 - mean_absolute_error: 0.1387 - val_loss: 0.1779 - val_mean_absolute_error: 0.1514
# Epoch 166/300
# 83/83 [==============================] - 7s 83ms/step - loss: 0.1810 - mean_absolute_error: 0.1559
# 32/32 [==============================] - 9s 273ms/step - loss: 0.2027 - mean_absolute_error: 0.1756 - val_loss: 0.1810 - val_mean_absolute_error: 0.1559
# Epoch 167/300
# 83/83 [==============================] - 7s 84ms/step - loss: 0.1893 - mean_absolute_error: 0.1633
# 32/32 [==============================] - 9s 277ms/step - loss: 0.1871 - mean_absolute_error: 0.1580 - val_loss: 0.1893 - val_mean_absolute_error: 0.1633
# Epoch 168/300
# 83/83 [==============================] - 7s 85ms/step - loss: 0.1749 - mean_absolute_error: 0.1464
# 32/32 [==============================] - 9s 275ms/step - loss: 0.1920 - mean_absolute_error: 0.1595 - val_loss: 0.1749 - val_mean_absolute_error: 0.1464
# Epoch 169/300
# 83/83 [==============================] - 7s 85ms/step - loss: 0.1840 - mean_absolute_error: 0.1570
# 32/32 [==============================] - 9s 277ms/step - loss: 0.2086 - mean_absolute_error: 0.1762 - val_loss: 0.1840 - val_mean_absolute_error: 0.1570
# Epoch 170/300
# 83/83 [==============================] - 7s 87ms/step - loss: 0.1824 - mean_absolute_error: 0.1563
# 32/32 [==============================] - 9s 273ms/step - loss: 0.1726 - mean_absolute_error: 0.1439 - val_loss: 0.1824 - val_mean_absolute_error: 0.1563
# Epoch 171/300
# 83/83 [==============================] - 7s 87ms/step - loss: 0.1718 - mean_absolute_error: 0.1435
# 32/32 [==============================] - 9s 277ms/step - loss: 0.1771 - mean_absolute_error: 0.1513 - val_loss: 0.1718 - val_mean_absolute_error: 0.1435
# Epoch 172/300
# 83/83 [==============================] - 7s 82ms/step - loss: 0.1863 - mean_absolute_error: 0.1586
# 32/32 [==============================] - 9s 270ms/step - loss: 0.1961 - mean_absolute_error: 0.1684 - val_loss: 0.1863 - val_mean_absolute_error: 0.1586
# Epoch 173/300
# 83/83 [==============================] - 7s 83ms/step - loss: 0.1794 - mean_absolute_error: 0.1513: 2s - loss: 0.1718 - mean_
# 32/32 [==============================] - 9s 270ms/step - loss: 0.1771 - mean_absolute_error: 0.1545 - val_loss: 0.1794 - val_mean_absolute_error: 0.1513
# Epoch 174/300
# 83/83 [==============================] - 7s 84ms/step - loss: 0.1727 - mean_absolute_error: 0.1448
# 32/32 [==============================] - 9s 272ms/step - loss: 0.2136 - mean_absolute_error: 0.1806 - val_loss: 0.1727 - val_mean_absolute_error: 0.1448
# Epoch 175/300
# 83/83 [==============================] - 7s 84ms/step - loss: 0.1791 - mean_absolute_error: 0.1517
# 32/32 [==============================] - 9s 271ms/step - loss: 0.1653 - mean_absolute_error: 0.1368 - val_loss: 0.1791 - val_mean_absolute_error: 0.1517
# Epoch 176/300
# 83/83 [==============================] - 7s 85ms/step - loss: 0.1696 - mean_absolute_error: 0.1417
# 32/32 [==============================] - 9s 275ms/step - loss: 0.1746 - mean_absolute_error: 0.1454 - val_loss: 0.1696 - val_mean_absolute_error: 0.1417
# Epoch 177/300
# 83/83 [==============================] - 8s 91ms/step - loss: 0.1756 - mean_absolute_error: 0.1477
# 32/32 [==============================] - 9s 293ms/step - loss: 0.1773 - mean_absolute_error: 0.1439 - val_loss: 0.1756 - val_mean_absolute_error: 0.1477
# Epoch 178/300
# 83/83 [==============================] - 7s 83ms/step - loss: 0.1764 - mean_absolute_error: 0.1486
# 32/32 [==============================] - 8s 264ms/step - loss: 0.1941 - mean_absolute_error: 0.1617 - val_loss: 0.1764 - val_mean_absolute_error: 0.1486
# Epoch 179/300
# ...
# Epoch 242/300
# 83/83 [==============================] - 10s 119ms/step - loss: 0.1723 - mean_absolute_error: 0.1480
# 32/32 [==============================] - 12s 381ms/step - loss: 0.1987 - mean_absolute_error: 0.1705 - val_loss: 0.1723 - val_mean_absolute_error: 0.1480
# Epoch 243/300
# 83/83 [==============================] - 10s 121ms/step - loss: 0.1721 - mean_absolute_error: 0.1473
# 32/32 [==============================] - 12s 389ms/step - loss: 0.1589 - mean_absolute_error: 0.1326 - val_loss: 0.1721 - val_mean_absolute_error: 0.1473
# Epoch 244/300
# 83/83 [==============================] - 10s 122ms/step - loss: 0.1849 - mean_absolute_error: 0.1581
# 32/32 [==============================] - 12s 389ms/step - loss: 0.1688 - mean_absolute_error: 0.1379 - val_loss: 0.1849 - val_mean_absolute_error: 0.1581
# Epoch 245/300
# 83/83 [==============================] - 10s 125ms/step - loss: 0.1764 - mean_absolute_error: 0.1518
# 32/32 [==============================] - 13s 397ms/step - loss: 0.1925 - mean_absolute_error: 0.1605 - val_loss: 0.1764 - val_mean_absolute_error: 0.1518
# Epoch 246/300
# 83/83 [==============================] - 10s 124ms/step - loss: 0.1733 - mean_absolute_error: 0.1451
# 32/32 [==============================] - 13s 392ms/step - loss: 0.1738 - mean_absolute_error: 0.1493 - val_loss: 0.1733 - val_mean_absolute_error: 0.1451
# Epoch 247/300
# 83/83 [==============================] - 11s 127ms/step - loss: 0.1813 - mean_absolute_error: 0.1572
# 32/32 [==============================] - 13s 402ms/step - loss: 0.1806 - mean_absolute_error: 0.1536 - val_loss: 0.1813 - val_mean_absolute_error: 0.1572
# Epoch 248/300
# 83/83 [==============================] - 11s 130ms/step - loss: 0.1772 - mean_absolute_error: 0.1520
# 32/32 [==============================] - 13s 403ms/step - loss: 0.1685 - mean_absolute_error: 0.1380 - val_loss: 0.1772 - val_mean_absolute_error: 0.1520
# Epoch 249/300
# 83/83 [==============================] - 11s 127ms/step - loss: 0.1679 - mean_absolute_error: 0.14253s - loss: 0.1660 - mea
# 32/32 [==============================] - 13s 404ms/step - loss: 0.2082 - mean_absolute_error: 0.1759 - val_loss: 0.1679 - val_mean_absolute_error: 0.1425
# Epoch 250/300
# 83/83 [==============================] - 10s 122ms/step - loss: 0.1803 - mean_absolute_error: 0.1557
# 32/32 [==============================] - 12s 387ms/step - loss: 0.1784 - mean_absolute_error: 0.1449 - val_loss: 0.1803 - val_mean_absolute_error: 0.1557
# Epoch 251/300
# 83/83 [==============================] - 10s 120ms/step - loss: 0.1763 - mean_absolute_error: 0.1522
# 32/32 [==============================] - 12s 388ms/step - loss: 0.1618 - mean_absolute_error: 0.1355 - val_loss: 0.1763 - val_mean_absolute_error: 0.1522
# Epoch 252/300
# 83/83 [==============================] - 10s 122ms/step - loss: 0.1716 - mean_absolute_error: 0.1464
# 32/32 [==============================] - 13s 397ms/step - loss: 0.1823 - mean_absolute_error: 0.1543 - val_loss: 0.1716 - val_mean_absolute_error: 0.1464
# Epoch 253/300
# 83/83 [==============================] - 10s 124ms/step - loss: 0.1797 - mean_absolute_error: 0.15525s - lo
# 32/32 [==============================] - 13s 395ms/step - loss: 0.1666 - mean_absolute_error: 0.1424 - val_loss: 0.1797 - val_mean_absolute_error: 0.1552
# Epoch 254/300
# 83/83 [==============================] - 10s 122ms/step - loss: 0.1699 - mean_absolute_error: 0.1454
# 32/32 [==============================] - 13s 393ms/step - loss: 0.1918 - mean_absolute_error: 0.1621 - val_loss: 0.1699 - val_mean_absolute_error: 0.1454
# Epoch 255/300
# 83/83 [==============================] - 10s 118ms/step - loss: 0.1729 - mean_absolute_error: 0.1486
# 32/32 [==============================] - 12s 381ms/step - loss: 0.2126 - mean_absolute_error: 0.1809 - val_loss: 0.1729 - val_mean_absolute_error: 0.1486
# Epoch 256/300
# 83/83 [==============================] - 10s 118ms/step - loss: 0.1716 - mean_absolute_error: 0.1425
# 32/32 [==============================] - 12s 380ms/step - loss: 0.1445 - mean_absolute_error: 0.1213 - val_loss: 0.1716 - val_mean_absolute_error: 0.1425
# Epoch 257/300
# 83/83 [==============================] - 11s 133ms/step - loss: 0.1751 - mean_absolute_error: 0.1469
# 32/32 [==============================] - 14s 423ms/step - loss: 0.1771 - mean_absolute_error: 0.1493 - val_loss: 0.1751 - val_mean_absolute_error: 0.1469
# Epoch 258/300
# 83/83 [==============================] - 10s 123ms/step - loss: 0.1810 - mean_absolute_error: 0.1542
# 32/32 [==============================] - 13s 397ms/step - loss: 0.1681 - mean_absolute_error: 0.1435 - val_loss: 0.1810 - val_mean_absolute_error: 0.1542
# Epoch 259/300
# 83/83 [==============================] - 10s 120ms/step - loss: 0.1761 - mean_absolute_error: 0.1493
# 32/32 [==============================] - 12s 385ms/step - loss: 0.1867 - mean_absolute_error: 0.1580 - val_loss: 0.1761 - val_mean_absolute_error: 0.1493
# Epoch 260/300
# 83/83 [==============================] - 10s 124ms/step - loss: 0.1764 - mean_absolute_error: 0.15003s - loss: 0.1705 - mean_absolute_e - ETA: 2s - loss: 0.1720 - mean_absol
# 32/32 [==============================] - 13s 399ms/step - loss: 0.1732 - mean_absolute_error: 0.1454 - val_loss: 0.1764 - val_mean_absolute_error: 0.1500
# Epoch 261/300
# 83/83 [==============================] - 10s 118ms/step - loss: 0.1695 - mean_absolute_error: 0.1421
# 32/32 [==============================] - 12s 384ms/step - loss: 0.1840 - mean_absolute_error: 0.1565 - val_loss: 0.1695 - val_mean_absolute_error: 0.1421
# Epoch 262/300
# 83/83 [==============================] - 10s 124ms/step - loss: 0.1720 - mean_absolute_error: 0.1462
# 32/32 [==============================] - 13s 397ms/step - loss: 0.1736 - mean_absolute_error: 0.1440 - val_loss: 0.1720 - val_mean_absolute_error: 0.1462
# Epoch 263/300
# 83/83 [==============================] - 10s 118ms/step - loss: 0.1681 - mean_absolute_error: 0.1423
# 32/32 [==============================] - 12s 374ms/step - loss: 0.1640 - mean_absolute_error: 0.1399 - val_loss: 0.1681 - val_mean_absolute_error: 0.1423
# Epoch 264/300
# 83/83 [==============================] - 10s 123ms/step - loss: 0.1831 - mean_absolute_error: 0.1562
# 32/32 [==============================] - 13s 393ms/step - loss: 0.1494 - mean_absolute_error: 0.1251 - val_loss: 0.1831 - val_mean_absolute_error: 0.1562
# Epoch 265/300
# 83/83 [==============================] - 11s 129ms/step - loss: 0.1709 - mean_absolute_error: 0.1454
# 32/32 [==============================] - 13s 419ms/step - loss: 0.1648 - mean_absolute_error: 0.1331 - val_loss: 0.1709 - val_mean_absolute_error: 0.1454
# Epoch 266/300
# 83/83 [==============================] - 10s 115ms/step - loss: 0.1707 - mean_absolute_error: 0.1462
# 32/32 [==============================] - 12s 377ms/step - loss: 0.1579 - mean_absolute_error: 0.1304 - val_loss: 0.1707 - val_mean_absolute_error: 0.1462
# Epoch 267/300
# 83/83 [==============================] - 10s 120ms/step - loss: 0.1734 - mean_absolute_error: 0.1491
# 32/32 [==============================] - 12s 387ms/step - loss: 0.1764 - mean_absolute_error: 0.1503 - val_loss: 0.1734 - val_mean_absolute_error: 0.1491
# Epoch 268/300
# 83/83 [==============================] - 10s 117ms/step - loss: 0.1636 - mean_absolute_error: 0.1346
# 32/32 [==============================] - 12s 381ms/step - loss: 0.1830 - mean_absolute_error: 0.1559 - val_loss: 0.1636 - val_mean_absolute_error: 0.1346
# Epoch 269/300
# 83/83 [==============================] - 10s 120ms/step - loss: 0.1712 - mean_absolute_error: 0.1480
# 32/32 [==============================] - 12s 381ms/step - loss: 0.1695 - mean_absolute_error: 0.1407 - val_loss: 0.1712 - val_mean_absolute_error: 0.1480
# Epoch 270/300
# 83/83 [==============================] - 10s 124ms/step - loss: 0.1758 - mean_absolute_error: 0.1508
# 32/32 [==============================] - 12s 390ms/step - loss: 0.1975 - mean_absolute_error: 0.1642 - val_loss: 0.1758 - val_mean_absolute_error: 0.1508
# Epoch 271/300
# 83/83 [==============================] - 10s 125ms/step - loss: 0.1647 - mean_absolute_error: 0.1330
# 32/32 [==============================] - 13s 392ms/step - loss: 0.2104 - mean_absolute_error: 0.1729 - val_loss: 0.1647 - val_mean_absolute_error: 0.1330
# Epoch 272/300
# 83/83 [==============================] - 10s 122ms/step - loss: 0.1754 - mean_absolute_error: 0.1502
# 32/32 [==============================] - 12s 384ms/step - loss: 0.1630 - mean_absolute_error: 0.1319 - val_loss: 0.1754 - val_mean_absolute_error: 0.1502
# Epoch 273/300
# 83/83 [==============================] - 11s 130ms/step - loss: 0.1772 - mean_absolute_error: 0.1531
# 32/32 [==============================] - 13s 412ms/step - loss: 0.1757 - mean_absolute_error: 0.1454 - val_loss: 0.1772 - val_mean_absolute_error: 0.1531
# Epoch 274/300
# 83/83 [==============================] - 10s 124ms/step - loss: 0.1711 - mean_absolute_error: 0.1463
# 32/32 [==============================] - 13s 398ms/step - loss: 0.1855 - mean_absolute_error: 0.1530 - val_loss: 0.1711 - val_mean_absolute_error: 0.1463
# Epoch 275/300
# 83/83 [==============================] - 10s 119ms/step - loss: 0.1659 - mean_absolute_error: 0.1416
# 32/32 [==============================] - 12s 381ms/step - loss: 0.1897 - mean_absolute_error: 0.1606 - val_loss: 0.1659 - val_mean_absolute_error: 0.1416
# Epoch 276/300
# 83/83 [==============================] - 10s 122ms/step - loss: 0.1746 - mean_absolute_error: 0.1492
# 32/32 [==============================] - 12s 387ms/step - loss: 0.1651 - mean_absolute_error: 0.1419 - val_loss: 0.1746 - val_mean_absolute_error: 0.1492
# Epoch 277/300
# 83/83 [==============================] - 10s 118ms/step - loss: 0.1770 - mean_absolute_error: 0.1504
# 32/32 [==============================] - 12s 380ms/step - loss: 0.1773 - mean_absolute_error: 0.1449 - val_loss: 0.1770 - val_mean_absolute_error: 0.1504
# Epoch 278/300
# 83/83 [==============================] - 9s 114ms/step - loss: 0.1694 - mean_absolute_error: 0.1406
# 32/32 [==============================] - 12s 368ms/step - loss: 0.1771 - mean_absolute_error: 0.1492 - val_loss: 0.1694 - val_mean_absolute_error: 0.1406
# Epoch 279/300
# 83/83 [==============================] - 9s 114ms/step - loss: 0.1702 - mean_absolute_error: 0.1452
# 32/32 [==============================] - 12s 375ms/step - loss: 0.1744 - mean_absolute_error: 0.1433 - val_loss: 0.1702 - val_mean_absolute_error: 0.1452
# Epoch 280/300
# 83/83 [==============================] - 10s 117ms/step - loss: 0.1720 - mean_absolute_error: 0.1483
# 32/32 [==============================] - 12s 377ms/step - loss: 0.1604 - mean_absolute_error: 0.1333 - val_loss: 0.1720 - val_mean_absolute_error: 0.1483
# Epoch 281/300
# 83/83 [==============================] - 10s 120ms/step - loss: 0.1687 - mean_absolute_error: 0.1458
# 32/32 [==============================] - 13s 391ms/step - loss: 0.1886 - mean_absolute_error: 0.1578 - val_loss: 0.1687 - val_mean_absolute_error: 0.1458
# Epoch 282/300
# 83/83 [==============================] - 10s 125ms/step - loss: 0.1710 - mean_absolute_error: 0.1416
# 32/32 [==============================] - 13s 411ms/step - loss: 0.1655 - mean_absolute_error: 0.1408 - val_loss: 0.1710 - val_mean_absolute_error: 0.1416
# Epoch 283/300
# 83/83 [==============================] - 10s 121ms/step - loss: 0.1709 - mean_absolute_error: 0.1469
# 32/32 [==============================] - 13s 391ms/step - loss: 0.1801 - mean_absolute_error: 0.1495 - val_loss: 0.1709 - val_mean_absolute_error: 0.1469
# Epoch 284/300
# 83/83 [==============================] - 10s 121ms/step - loss: 0.1689 - mean_absolute_error: 0.14513s - loss: 0.1778 - mea
# 32/32 [==============================] - 13s 394ms/step - loss: 0.1929 - mean_absolute_error: 0.1625 - val_loss: 0.1689 - val_mean_absolute_error: 0.1451
# Epoch 285/300
# 83/83 [==============================] - 10s 122ms/step - loss: 0.1654 - mean_absolute_error: 0.1414
# 32/32 [==============================] - 13s 394ms/step - loss: 0.2075 - mean_absolute_error: 0.1773 - val_loss: 0.1654 - val_mean_absolute_error: 0.1414
# Epoch 286/300
# 83/83 [==============================] - 10s 118ms/step - loss: 0.1758 - mean_absolute_error: 0.1506
# 32/32 [==============================] - 12s 381ms/step - loss: 0.1616 - mean_absolute_error: 0.1344 - val_loss: 0.1758 - val_mean_absolute_error: 0.1506
# Epoch 287/300
# 83/83 [==============================] - 10s 119ms/step - loss: 0.1694 - mean_absolute_error: 0.1437
# 32/32 [==============================] - 12s 384ms/step - loss: 0.1574 - mean_absolute_error: 0.1275 - val_loss: 0.1694 - val_mean_absolute_error: 0.1437
# Epoch 288/300
# 83/83 [==============================] - 10s 118ms/step - loss: 0.1738 - mean_absolute_error: 0.1484
# 32/32 [==============================] - 12s 377ms/step - loss: 0.1803 - mean_absolute_error: 0.1542 - val_loss: 0.1738 - val_mean_absolute_error: 0.1484
# Epoch 289/300
# 83/83 [==============================] - 10s 122ms/step - loss: 0.1651 - mean_absolute_error: 0.1401
# 32/32 [==============================] - 13s 391ms/step - loss: 0.1870 - mean_absolute_error: 0.1512 - val_loss: 0.1651 - val_mean_absolute_error: 0.1401
# Epoch 290/300
# 83/83 [==============================] - 10s 125ms/step - loss: 0.1682 - mean_absolute_error: 0.1417
# 32/32 [==============================] - 13s 400ms/step - loss: 0.1489 - mean_absolute_error: 0.1202 - val_loss: 0.1682 - val_mean_absolute_error: 0.1417
# Epoch 291/300
# 83/83 [==============================] - 10s 116ms/step - loss: 0.1673 - mean_absolute_error: 0.1416
# 32/32 [==============================] - 12s 371ms/step - loss: 0.1707 - mean_absolute_error: 0.1443 - val_loss: 0.1673 - val_mean_absolute_error: 0.1416
# Epoch 292/300
# 83/83 [==============================] - 10s 120ms/step - loss: 0.1662 - mean_absolute_error: 0.1423
# 32/32 [==============================] - 12s 383ms/step - loss: 0.1651 - mean_absolute_error: 0.1388 - val_loss: 0.1662 - val_mean_absolute_error: 0.1423
# Epoch 293/300
# 83/83 [==============================] - 10s 124ms/step - loss: 0.1662 - mean_absolute_error: 0.1410
# 32/32 [==============================] - 12s 388ms/step - loss: 0.1941 - mean_absolute_error: 0.1685 - val_loss: 0.1662 - val_mean_absolute_error: 0.1410
# Epoch 294/300
# 83/83 [==============================] - 10s 116ms/step - loss: 0.1829 - mean_absolute_error: 0.1580
# 32/32 [==============================] - 12s 368ms/step - loss: 0.1679 - mean_absolute_error: 0.1405 - val_loss: 0.1829 - val_mean_absolute_error: 0.1580
# Epoch 295/300
# 83/83 [==============================] - 10s 119ms/step - loss: 0.1855 - mean_absolute_error: 0.1571
# 32/32 [==============================] - 12s 382ms/step - loss: 0.1819 - mean_absolute_error: 0.1604 - val_loss: 0.1855 - val_mean_absolute_error: 0.1571
# Epoch 296/300
# 83/83 [==============================] - 10s 121ms/step - loss: 0.1796 - mean_absolute_error: 0.1537
# 32/32 [==============================] - 13s 392ms/step - loss: 0.1740 - mean_absolute_error: 0.1523 - val_loss: 0.1796 - val_mean_absolute_error: 0.1537
# Epoch 297/300
# 83/83 [==============================] - 10s 116ms/step - loss: 0.1701 - mean_absolute_error: 0.1458
# 32/32 [==============================] - 12s 379ms/step - loss: 0.1879 - mean_absolute_error: 0.1593 - val_loss: 0.1701 - val_mean_absolute_error: 0.1458
# Epoch 298/300
# 83/83 [==============================] - 10s 123ms/step - loss: 0.1762 - mean_absolute_error: 0.1481
# 32/32 [==============================] - 13s 394ms/step - loss: 0.1798 - mean_absolute_error: 0.1460 - val_loss: 0.1762 - val_mean_absolute_error: 0.1481
# Epoch 299/300
# 83/83 [==============================] - 10s 117ms/step - loss: 0.1699 - mean_absolute_error: 0.1434
# 32/32 [==============================] - 12s 386ms/step - loss: 0.1789 - mean_absolute_error: 0.1510 - val_loss: 0.1699 - val_mean_absolute_error: 0.1434
# Epoch 300/300
# 83/83 [==============================] - 10s 116ms/step - loss: 0.1680 - mean_absolute_error: 0.1435
# 32/32 [==============================] - 12s 374ms/step - loss: 0.2041 - mean_absolute_error: 0.1646 - val_loss: 0.1680 - val_mean_absolute_error: 0.1435

# %% [markdown]
# ## Load model (optional)

# %%
'''
# Load model
model_dir = "models/20201209_dense-rmse-position5-trajectory-100-batchnorm-64-128-256-128-64-16-3/"
model_name = "20201209_dense-rmse-position5-trajectory-100-batchnorm-64-128-256-128-64-16-3.h5"
model_path = os.path.join(model_dir, model_name)
model = keras.models.load_model(model_path,
                                custom_objects={'root_mean_squared_error': root_mean_squared_error})

eval_his = model.evaluate_generator(test_generator(), steps=len(test_list), verbose=1)
'''

# %% [markdown]
# ## Model evaluate

# %%
# Predict
predict = model.predict_generator(test_generator(), verbose=1, steps=len(test_list))

predict[:, 0] = predict[:, 0] * 120 + 20
predict[:, 1] = predict[:, 1] * 60 + 10
predict[:, 2] = predict[:, 2] * 30 + 10

# Present as dataframe
df = pd.DataFrame()
for i, (_, y_test, _) in enumerate(test_generator()):
    df.loc[i, 'Speed'] = y_test[:, 0]
    df.loc[i, 'Angle_H'] = y_test[:, 1]
    df.loc[i, 'Angle_V'] = y_test[:, 2]
    df.loc[i, 'Predict(Speed)'] = predict[:,0][i]
    df.loc[i, 'Predict(Angle_H)'] = predict[:,1][i]
    df.loc[i, 'Predict(Angle_V)'] = predict[:,2][i]

# Adjust data type
df = df.astype({'Speed': 'int32',
                'Angle_H': 'int32',
                'Angle_V': 'int32',
                'Predict(Speed)': 'int32',
                'Predict(Angle_H)': 'int32',
                'Predict(Angle_V)': 'int32'})

# Caculate Loss
for i in df.index:
    target = df.loc[i, ['Speed', 'Angle_H', 'Angle_V']].tolist()
    target[0] = (target[0]-20)/120
    target[1] = (target[1]-10)/60
    target[2] = (target[2]-10)/30
    pred = df.loc[i, ['Predict(Speed)', 'Predict(Angle_H)', 'Predict(Angle_V)']].tolist()
    pred[0] = (pred[0]-20)/120
    pred[1] = (pred[1]-10)/60
    pred[2] = (pred[2]-10)/30
    
    mae = mean_absolute_error(target, pred)
    rmse = np.sqrt(mean_squared_error(target, pred))
    df.loc[i, 'MAE'] = np.around(mae, decimals=6)
    df.loc[i, 'RMSE'] = np.around(rmse, decimals=6)

df.sort_values("Speed", inplace=True)
df

# %% [markdown]
# ## Save evaluate results

# %%
# Caculate mean loss
last_idx = len(df)
df.loc[last_idx, 'MAE'] = df['MAE'].mean()
df.loc[last_idx, 'RMSE'] = df['RMSE'].mean()

# Save result to csv
result_dir = os.path.join(os.getcwd(), 'predictions/')
checkDirExist(result_dir)
df.to_csv(os.path.join(result_dir, model_name+'.csv'), index=False)

# %% [markdown]
# ## Plot history

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('mae')
plt.ylabel('mae')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ## Convert Jupyter(.ipynb) to Python(.py) (optional)

# %%
# jupyter nbconvert --to script dense_regression_rmse_trajectory.ipynb
